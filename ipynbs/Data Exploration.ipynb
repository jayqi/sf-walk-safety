# %%
import pandas as pd
import numpy as np
import json

# %%
data = pd.read_csv('../rawdata/SFPD_Incidents_-_from_1_January_2003.csv')
data.head(5)
# Out:
#    IncidntNum      Category                         Descript DayOfWeek  \
# 0   160213624       ROBBERY            ROBBERY, BODILY FORCE    Sunday
# 1   160213599       ASSAULT                          BATTERY    Sunday
# 2   160213599       ASSAULT  AGGRAVATED ASSAULT WITH A KNIFE    Sunday
# 3   160213599       ROBBERY      ROBBERY, ARMED WITH A KNIFE    Sunday
# 4   160214763  NON-CRIMINAL                    LOST PROPERTY    Sunday
#
#          Date   Time PdDistrict Resolution                     Address  \
# 0  03/13/2016  23:50    CENTRAL       NONE  VANNESS AV / NORTHPOINT ST
# 1  03/13/2016  23:48   NORTHERN       NONE    1800 Block of FILBERT ST
# 2  03/13/2016  23:48   NORTHERN       NONE    1800 Block of FILBERT ST
# 3  03/13/2016  23:48   NORTHERN       NONE    1800 Block of FILBERT ST
# 4  03/13/2016  23:45    CENTRAL       NONE       400 Block of GEARY ST
#
#             X          Y                               Location  \
# ...

# %%
data.dtypes
# Out:
# IncidntNum      int64
# Category       object
# Descript       object
# DayOfWeek      object
# Date           object
# Time           object
# PdDistrict     object
# Resolution     object
# Address        object
# X             float64
# Y             float64
# Location       object
# PdId            int64
# dtype: object

# %%
#data.IncidntNum = data.IncidntNum.astype(str)
#data.Date = pd.to_datetime(data.Date)
#data.Date = data.Date.dt.date
#data.Time = data.Date.dt.time
#data.dtypes

# %% [markdown]
# ## San Francisco Police Dept Incident Reports Dataset

# %%
data.head(5)
# Out:
#    IncidntNum      Category                         Descript DayOfWeek  \
# 0   160213624       ROBBERY            ROBBERY, BODILY FORCE    Sunday
# 1   160213599       ASSAULT                          BATTERY    Sunday
# 2   160213599       ASSAULT  AGGRAVATED ASSAULT WITH A KNIFE    Sunday
# 3   160213599       ROBBERY      ROBBERY, ARMED WITH A KNIFE    Sunday
# 4   160214763  NON-CRIMINAL                    LOST PROPERTY    Sunday
#
#          Date   Time PdDistrict Resolution                     Address  \
# 0  03/13/2016  23:50    CENTRAL       NONE  VANNESS AV / NORTHPOINT ST
# 1  03/13/2016  23:48   NORTHERN       NONE    1800 Block of FILBERT ST
# 2  03/13/2016  23:48   NORTHERN       NONE    1800 Block of FILBERT ST
# 3  03/13/2016  23:48   NORTHERN       NONE    1800 Block of FILBERT ST
# 4  03/13/2016  23:45    CENTRAL       NONE       400 Block of GEARY ST
#
#             X          Y                               Location  \
# ...

# %% [markdown]
# ### Counts of all categories

# %%
data['Category'].value_counts()
# Out:
# LARCENY/THEFT                  385966
# OTHER OFFENSES                 269325
# NON-CRIMINAL                   201042
# ASSAULT                        165385
# VEHICLE THEFT                  114290
# DRUG/NARCOTIC                  111454
# VANDALISM                       96388
# WARRANTS                        89807
# BURGLARY                        78997
# SUSPICIOUS OCC                  67818
# MISSING PERSON                  55599
# ROBBERY                         48734
# FRAUD                           36018
# FORGERY/COUNTERFEITING          21806
# SECONDARY CODES                 21644
# WEAPON LAWS                     18538
# TRESPASS                        15806
# PROSTITUTION                    15657
# STOLEN PROPERTY                 10096
# SEX OFFENSES, FORCIBLE           9551
# DRUNKENNESS                      9036
# DISORDERLY CONDUCT               8993
# RECOVERED VEHICLE                6346
# DRIVING UNDER THE INFLUENCE      4958
# KIDNAPPING                       4853
# ...

# %% [markdown]
# ### Counts of all Descripts

# %%
datacounts = data[['Category','Descript']].groupby(['Category','Descript']).size()
print datacounts
with open("descript_counts.txt", "w") as descript_counts_file:
    descript_counts_file.write(datacounts.to_string())
# Out:
# Category     Descript
# ARSON        ARSON                                                        999
#              ARSON OF A COMMERCIAL BUILDING                               127
#              ARSON OF A POLICE BUILDING                                     4
#              ARSON OF A POLICE VEHICLE                                      2
#              ARSON OF A VACANT BUILDING                                    72
#              ARSON OF A VEHICLE                                          1297
#              ARSON OF AN INHABITED DWELLING                               450
#              ARSON WITH GREAT BODILY INJURY                                 4
#              ATTEMPTED ARSON                                              258
#              FIRE, UNLAWFULLY CAUSING                                      72
# ASSAULT      AGGRAVATED ASSAULT OF POLICE OFFICER, SNIPING                  2
#              AGGRAVATED ASSAULT OF POLICE OFFICER,BODILY FORCE            346
# ...

# %% [markdown]
# ### See descripts in given category

# %%
data[data.Category == 'ASSAULT'].groupby('Descript').size()[1:50]
# Out:
# Descript
# AGGRAVATED ASSAULT OF POLICE OFFICER,BODILY FORCE                346
# AGGRAVATED ASSAULT ON POLICE OFFICER WITH A GUN                   14
# AGGRAVATED ASSAULT ON POLICE OFFICER WITH A KNIFE                 45
# AGGRAVATED ASSAULT WITH A DEADLY WEAPON                        13880
# AGGRAVATED ASSAULT WITH A GUN                                   2228
# AGGRAVATED ASSAULT WITH A KNIFE                                 5265
# AGGRAVATED ASSAULT WITH BODILY FORCE                           10657
# ASSAULT                                                         1115
# ASSAULT BY POISONING                                              15
# ASSAULT BY POLICE OFFICER                                         10
# ASSAULT ON A POLICE OFFICER WITH A DEADLY WEAPON                 501
# ASSAULT OR ATTEMPTED MURDER UPON GOV'T OFFICERS                    2
# ASSAULT WITH CAUSTIC CHEMICALS                                   905
# ...
