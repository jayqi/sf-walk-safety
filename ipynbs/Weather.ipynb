# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
path = r"../rawdata/noaa-weather-downtown-sf.csv"

conv = {
        'DATE' : lambda x: dt.datetime.strptime(str(x),"%Y%m%d").date(),
    }

rawdf = pd.read_csv(path,converters = conv)



print rawdf.shape
print rawdf.dtypes
rawdf.tail(5)
# Out:
# (4836, 41)
# STATION                   object
# STATION_NAME              object
# ELEVATION                float64
# LATITUDE                 float64
# LONGITUDE                float64
# DATE                      object
# PRCP                       int64
# Measurement Flag          object
# Quality Flag              object
# Source Flag               object
# Time of Observation        int64
# SNWD                       int64
# Measurement Flag.1        object
# Quality Flag.1            object
# Source Flag.1             object
# Time of Observation.1      int64
# SNOW                       int64
# Measurement Flag.2        object
# Quality Flag.2            object
# Source Flag.2             object
# Time of Observation.2      int64
# TMAX                       int64
# Measurement Flag.3        object
# Quality Flag.3            object
# Source Flag.3             object
# Time of Observation.3      int64
# TMIN                       int64
# Measurement Flag.4        object
# ...

# %%
dropcols = ['STATION','STATION_NAME','ELEVATION', 'LATITUDE', 'LONGITUDE','Time of Observation',
            'SNOW', 'Measurement Flag.2', 'Quality Flag.2', 'Source Flag.2',
            'SNWD', 'Measurement Flag.1', 'Quality Flag.1', 'Source Flag.1',
            'TOBS', 'Measurement Flag.5', 'Quality Flag.5', 'Source Flag.5',
            'WT11', 'Measurement Flag.6', 'Quality Flag.6', 'Source Flag.6',
           'Time of Observation.1','Time of Observation.2','Time of Observation.3',
            'Time of Observation.4','Time of Observation.5','Time of Observation.6']
df = rawdf.drop(dropcols,axis=1)
df[df < -1000] = np.nan
df.TMAX = df.TMAX.astype(float)/10.
df.TMIN = df.TMIN.astype(float)/10.
df.tail(200)
# Out:
#      DATE  PRCP Measurement Flag Quality Flag Source Flag  TMAX  \
# 4636  NaN     0              NaN          NaN         NaN  20.6
# 4637  NaN     0              NaN          NaN         NaN  21.7
# 4638  NaN     0              NaN          NaN         NaN  20.0
# 4639  NaN     0              NaN          NaN         NaN  19.4
# 4640  NaN     3              NaN          NaN         NaN  17.8
# 4641  NaN     8              NaN          NaN         NaN  20.6
# 4642  NaN     0              NaN          NaN         NaN  19.4
# 4643  NaN     0              NaN          NaN         NaN  23.3
# 4644  NaN     0              NaN          NaN         NaN  29.4
# 4645  NaN     0              NaN          NaN         NaN  33.9
# 4646  NaN     0              NaN          NaN         NaN  31.7
# 4647  NaN     0              NaN          NaN         NaN  16.7
# 4648  NaN     0              NaN          NaN         NaN  20.6
# 4649  NaN     0              NaN          NaN         NaN  32.2
# ...

# %%
df['PRCP'].describe()
# Out:
# count    4836.000000
# mean       15.068238
# std        54.591978
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max       864.000000
# Name: PRCP, dtype: float64

# %%
df['Quality Flag.3'].value_counts()
# Out:
# Series([], Name: Quality Flag.3, dtype: int64)

# %%
df[(df['Quality Flag.3'] != " ")]
# Out:
#      DATE  PRCP Measurement Flag Quality Flag Source Flag  TMAX  \
# 0     NaN     0              NaN          NaN         NaN  15.0
# 1     NaN     0              NaN          NaN         NaN  13.9
# 2     NaN     0              NaN          NaN         NaN  17.2
# 3     NaN     0              NaN          NaN         NaN  18.9
# 4     NaN     0              NaN          NaN         NaN  20.6
# 5     NaN     0              NaN          NaN         NaN  20.6
# 6     NaN     0              NaN          NaN         NaN  18.9
# 7     NaN     0              NaN          NaN         NaN  17.2
# 8     NaN   251              NaN          NaN         NaN  13.3
# 9     NaN    33              NaN          NaN         NaN  16.1
# 10    NaN     0              NaN          NaN         NaN  15.6
# 11    NaN    15              NaN          NaN         NaN  16.1
# 12    NaN     0              NaN          NaN         NaN  17.8
# 13    NaN     0              NaN          NaN         NaN  16.7
# ...

# %%
df[(df['Quality Flag.4'] != " ")]
# Out:
#      DATE  PRCP Measurement Flag Quality Flag Source Flag  TMAX  \
# 0     NaN     0              NaN          NaN         NaN  15.0
# 1     NaN     0              NaN          NaN         NaN  13.9
# 2     NaN     0              NaN          NaN         NaN  17.2
# 3     NaN     0              NaN          NaN         NaN  18.9
# 4     NaN     0              NaN          NaN         NaN  20.6
# 5     NaN     0              NaN          NaN         NaN  20.6
# 6     NaN     0              NaN          NaN         NaN  18.9
# 7     NaN     0              NaN          NaN         NaN  17.2
# 8     NaN   251              NaN          NaN         NaN  13.3
# 9     NaN    33              NaN          NaN         NaN  16.1
# 10    NaN     0              NaN          NaN         NaN  15.6
# 11    NaN    15              NaN          NaN         NaN  16.1
# 12    NaN     0              NaN          NaN         NaN  17.8
# 13    NaN     0              NaN          NaN         NaN  16.7
# ...

# %%
df[1955:1965]
# Out:
#      DATE  PRCP Measurement Flag Quality Flag Source Flag  TMAX  \
# 1955  NaN     0              NaN          NaN         NaN  16.1
# 1956  NaN     0              NaN          NaN         NaN  16.7
# 1957  NaN     0              NaN          NaN         NaN  15.6
# 1958  NaN     0              NaN          NaN         NaN  16.1
# 1959  NaN     0              NaN          NaN         NaN  23.9
# 1960  NaN     0              NaN          NaN         NaN  27.2
# 1961  NaN     0              NaN          NaN         NaN  36.1
# 1962  NaN     0              NaN          NaN         NaN  33.3
# 1963  NaN     0              NaN          NaN         NaN  20.0
# 1964  NaN     0              NaN          NaN         NaN  16.1
#
#      Measurement Flag.3 Quality Flag.3 Source Flag.3  TMIN Measurement Flag.4  \
# 1955                NaN            NaN           NaN   8.3                NaN
# 1956                NaN            NaN           NaN   8.3                NaN
# ...

# %%
df[2240:2250]
# Out:
#      DATE  PRCP Measurement Flag Quality Flag Source Flag  TMAX  \
# 2240  NaN     0              NaN          NaN         NaN  15.0
# 2241  NaN     0              NaN          NaN         NaN  17.8
# 2242  NaN     0              NaN          NaN         NaN  18.3
# 2243  NaN     0              NaN          NaN         NaN  10.6
# 2244  NaN   315              NaN          NaN         NaN  14.4
# 2245  NaN    89              NaN          NaN         NaN  15.0
# 2246  NaN     3              NaN          NaN         NaN  11.1
# 2247  NaN    53              NaN          NaN         NaN  16.1
# 2248  NaN    18              NaN          NaN         NaN  15.0
# 2249  NaN     0              NaN          NaN         NaN  15.0
#
#      Measurement Flag.3 Quality Flag.3 Source Flag.3  TMIN Measurement Flag.4  \
# 2240                NaN            NaN           NaN   8.3                NaN
# 2241                NaN            NaN           NaN   7.8                NaN
# ...

# %%
df[2242:2245]
# Out:
#      DATE  PRCP Measurement Flag Quality Flag Source Flag  TMAX  \
# 2242  NaN     0              NaN          NaN         NaN  18.3
# 2243  NaN     0              NaN          NaN         NaN  10.6
# 2244  NaN   315              NaN          NaN         NaN  14.4
#
#      Measurement Flag.3 Quality Flag.3 Source Flag.3  TMIN Measurement Flag.4  \
# 2242                NaN            NaN           NaN   9.4                NaN
# 2243                NaN            NaN           NaN  10.0                NaN
# 2244                NaN            NaN           NaN  11.7                NaN
#
#      Quality Flag.4 Source Flag.4
# 2242            NaN           NaN
# 2243            NaN           NaN
# 2244            NaN           NaN

# %%
df[(df['DATE'] == 20080125)]
# Out:
# Empty DataFrame
# Columns: [DATE, PRCP, Measurement Flag, Quality Flag, Source Flag, TMAX, Measurement Flag.3, Quality Flag.3, Source Flag.3, TMIN, Measurement Flag.4, Quality Flag.4, Source Flag.4]
# Index: []

# %% [markdown]
# ## Actual processing

# %%
df = rawdf[['DATE','PRCP','TMAX','TMIN']].copy()
df.loc[2243,'TMAX'] = np.mean([df.TMAX[2242],df.TMAX[2244]])
df.PRCP = df.PRCP.astype(float)/10.
df.TMAX = df.TMAX.astype(float)/10.
df.TMIN = df.TMIN.astype(float)/10.
df[2242:2245]
# Out:
#             DATE  PRCP   TMAX  TMIN
# 2242  2009-02-20   0.0  18.30   9.4
# 2243  2009-02-21   0.0  16.35  10.0
# 2244  2009-02-22  31.5  14.40  11.7

# %%
df.dtypes
# Out:
# DATE     object
# PRCP    float64
# TMAX    float64
# TMIN    float64
# dtype: object

# %%
df.PRCP.describe()
# Out:
# count    4836.000000
# mean        1.506824
# std         5.459198
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max        86.400000
# Name: PRCP, dtype: float64

# %%
rawdf.head(3)

def celsius2fahrenheit(T):
    return T*1.8 + 32

print rawdf.TMAX.apply(lambda x: celsius2fahrenheit(x/10.)).describe()
print rawdf.TMIN.apply(lambda x: celsius2fahrenheit(x/10.)).describe()
# Out:
# count    4836.000000
# mean       64.068548
# std         7.370741
# min        44.060000
# 25%        59.000000
# 50%        62.960000
# 75%        68.000000
# max        98.060000
# Name: TMAX, dtype: float64
# count    4836.000000
# mean       51.376985
# std         4.515807
# min        35.960000
# 25%        48.020000
# 50%        51.080000
# 75%        53.960000
# max        68.000000
# Name: TMIN, dtype: float64

# %% [markdown]
# ## Read weather, clean, save to pickle

# %%
import pandas as pd
import numpy as np
import datetime as dt

path = r"../rawdata/noaa-weather-downtown-sf.csv"

conv = {
        'DATE' : lambda x: dt.datetime.strptime(str(x),"%Y%m%d").date(),
    }

rawdf = pd.read_csv(path,converters = conv)

df = rawdf[['DATE','PRCP','TMAX','TMIN']].copy()
df.loc[2243,'TMAX'] = np.mean([df.TMAX[2242],df.TMAX[2244]])
df.PRCP = df.PRCP.astype(float)/10.
df.TMAX = df.TMAX.astype(float)/10.
df.TMIN = df.TMIN.astype(float)/10.

path = r"../data/noaa-weather-downtown-sf.p"

df.to_pickle(path)
